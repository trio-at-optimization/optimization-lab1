# %% [markdown]
# $$\texttt{Реализуйте генератор случайных квадратичных функций}~n~\texttt{переменных с числом обусловленности}~k$$

# %%
import numpy as np
import random
import sys

# Generating function
def generate(n, k):
    rng = np.random.default_rng()
    MIN =  random.random() * random.randint(0, sys.maxsize // (2 ** 32) + 1)
    MAX = MIN * k
    q = np.concatenate([[MIN, MAX], rng.integers(low = (MIN + 1), high = (MAX - 1), size = (n - 2))])

    return q

# Testing generating function
n, k = 10, 5
array = generate(n, k)

answer = " + ".join([f'{array[i]} \\cdot x^2_{i}' for i in range(len(array))])

print(answer)
# Out:
# 97308863.29872756 \cdot x^2_0 + 486544316.4936378 \cdot x^2_1 + 361712433.0 \cdot x^2_2 + 464080488.0 \cdot x^2_3 + 178121314.0 \cdot x^2_4 + 467321649.0 \cdot x^2_5 + 460024751.0 \cdot x^2_6 + 181172819.0 \cdot x^2_7 + 224844731.0 \cdot x^2_8 + 285401277.0 \cdot x^2_9
